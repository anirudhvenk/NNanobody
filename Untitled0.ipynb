# %%
# %cd drive/MyDrive/github/NNanobody
# Out:
# /content/drive/MyDrive/github/NNanobody

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/github/NNanobody/.git/

# %%
# !git remote add origin https://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@github.com/anirudhvenk/
